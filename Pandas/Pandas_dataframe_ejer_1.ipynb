# %% [markdown]
# # Ejercicios Pandas DataFrames 01

# %% [markdown]
# 1. Escribe un programa Pandas para conectarte a la base de datos datafundamentals y carga los pagos como un dataframe

# %%
#!pip install psycopg2-binary

# %%
#copiamos la función de conexión a bbdd
import psycopg2

def conexion_servidor():

    PGHOST='ep-sweet-sound-a2m88zrk.eu-central-1.aws.neon.tech'
    PGDATABASE='datafundamentamentals'
    PGUSER='datafundamentamentals_owner'
    PGPASSWORD='QhJH3pb0gDfv'
    conn = None
    try:
        conn = psycopg2.connect(database=PGDATABASE, user=PGUSER, password=PGPASSWORD, host=PGHOST, port=5432)
        print("Database conn successful")
    except Error as err:
        print(f"Error: '{err}'")

    return conn

connection = conexion_servidor()
connection.close()
# Out:
# Database conn successful

# %%
import pandas as pd

# %%
conex=conexion_servidor()
df=pd.read_sql_query("SELECT * FROM payments",conex)
conex.close()
df
# Out:
# Database conn successful
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customernumber  259 non-null    int64
#  1   checknumber     259 non-null    object
#  2   paymentdate     259 non-null    object
#  3   amount          259 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.2+ KB

# %%
df.head()
# Out:
#    customernumber checknumber paymentdate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14
# 3             112    BO864823  2004-12-17  14191.12
# 4             112     HQ55022  2003-06-06  32641.98

# %%
df.describe()
# Out:
#        customernumber         amount
# count      259.000000     259.000000
# mean       270.779923   32419.803707
# std        120.336164   20633.076867
# min        103.000000    1128.200000
# 25%        161.000000   17195.910000
# 50%        250.000000   32077.440000
# 75%        359.500000   44989.560000
# max        496.000000  120166.580000

# %% [markdown]
# 2. Escribe un programa Pandas para conectarte a la base de datos datafundamentals y guardar el df de pagos en una tabla nueva. Luego muestra las tablas en la bbdd y comprueba que existe la nueva tabla.
#
# **Tip:** Usar sqlalchemy (https://www.sqlalchemy.org/)
# ```
# # !pip install sqlalchemy
#
# from sqlalchemy import create_engine
# engine = create_engine('db_url')
# df.sql('table_name',engine)
# ```

# %%
#!pip install sqlalchemy; esta librería es para utilizar múltiples bbdd y conexiones;
# da error porque la versión del pandas de la máquina es antigua

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://datafundamentamentals_owner:QhJH3pb0gDfv@ep-sweet-sound-a2m88zrk-pooler.eu-central-1.aws.neon.tech/datafundamentamentals?sslmode=require')
df[10].sql('Pagos2',engine)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File /anaconda/envs/azureml_py38/lib/python3.10/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 3. Escribe un programa Pandas para seleccionar filas donde el valor de la columna "amount" sea mayor que 400.

# %%
df
# Out:
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %%
mask=df['amount']>400 #Recuerda la condición fuera del corchete
df[mask]
# Out:
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %%
# en una sola línea
df[df['amount']>400]
# Out:
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %% [markdown]
# 4. Escribe un programa Pandas para seleccionar solo las columnas "checknumber" y "paymentdate" del DataFrame.

# %%
df[['checknumber','paymentdate']] #se pasa una lista
# Out:
#     checknumber paymentdate
# 0      HQ336336  2004-10-19
# 1      JM555205  2003-06-05
# 2      OM314933  2004-12-18
# 3      BO864823  2004-12-17
# 4       HQ55022  2003-06-06
# ..          ...         ...
# 254    BH167026  2003-12-26
# 255    FN155234  2004-05-14
# 256    EU531600  2005-05-25
# 257    MB342426  2003-07-16
# 258     MN89921  2004-12-31
#
# [259 rows x 2 columns]

# %%
# utilizando loc
df.loc[:,['checknumber','paymentdate']]
# Out:
#     checknumber paymentdate
# 0      HQ336336  2004-10-19
# 1      JM555205  2003-06-05
# 2      OM314933  2004-12-18
# 3      BO864823  2004-12-17
# 4       HQ55022  2003-06-06
# ..          ...         ...
# 254    BH167026  2003-12-26
# 255    FN155234  2004-05-14
# 256    EU531600  2005-05-25
# 257    MB342426  2003-07-16
# 258     MN89921  2004-12-31
#
# [259 rows x 2 columns]

# %% [markdown]
# 5. Escribe un programa Pandas para definir un MultiIndex (multi-índice: varios índices para cada fila), basados en 2 columnas, para:
# - acceder a datos específicos mediante él
# - segmentar el DataFrame en función de los niveles de MultiIndex.

# %%
df
# Out:
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %%
df2=df.set_index(['customernumber','checknumber']) #pone las columnas seleccionadas como índices
df2
# Out:
#                            paymentdate    amount
# customernumber checknumber
# 103            HQ336336     2004-10-19   6066.78
#                JM555205     2003-06-05  14571.44
#                OM314933     2004-12-18   1676.14
# 112            BO864823     2004-12-17  14191.12
#                HQ55022      2003-06-06  32641.98
# ...                                ...       ...
# 495            BH167026     2003-12-26  59265.14
#                FN155234     2004-05-14   6276.60
# 496            EU531600     2005-05-25  30253.75
#                MB342426     2003-07-16  32077.44
#                MN89921      2004-12-31  52166.00
#
# [259 rows x 2 columns]

# %%
df2.loc[103,'HQ336336']
# Out:
# paymentdate    2004-10-19
# amount            6066.78
# Name: (103, HQ336336), dtype: object

# %%
df2.loc[103:112,:]
# Out:
#                            paymentdate    amount
# customernumber checknumber
# 103            HQ336336     2004-10-19   6066.78
#                JM555205     2003-06-05  14571.44
#                OM314933     2004-12-18   1676.14
# 112            BO864823     2004-12-17  14191.12
#                HQ55022      2003-06-06  32641.98
#                ND748579     2004-08-20  33347.88

# %% [markdown]
# 5. Escribe un programa Pandas para seleccionar las primeras tres filas usando iloc.

# %%
df.iloc[:3,:]
# Out:
#    customernumber checknumber paymentdate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14

# %% [markdown]
# 6. Escribe un programa Pandas para usar loc para seleccionar filas aplicando una condición dada en 2 columas.

# %%
df.loc[(df['amount']>400) & (df['customernumber']>200)] #ojo con esta estructura, de memoria!
 #hay que poner la columna con el df y las condiciones en () y con & (no and) o lo q corresponda
# Out:
#      customernumber checknumber paymentdate    amount
# 97              201    DP677013  2003-10-20  23908.24
# 98              201    OO846801  2004-06-15  37258.94
# 99              202    HI358554  2003-12-18  36527.61
# 100             202    IQ627690  2004-11-08  33594.58
# 101             204    GC697638  2004-08-13  51152.86
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [162 rows x 4 columns]

# %%
# con máscara
mask=(df['amount']>400) & (df['customernumber']>200)
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 254     True
# 255     True
# 256     True
# 257     True
# 258     True
# Length: 259, dtype: bool

# %%
df[mask]
# Out:
#      customernumber checknumber paymentdate    amount
# 97              201    DP677013  2003-10-20  23908.24
# 98              201    OO846801  2004-06-15  37258.94
# 99              202    HI358554  2003-12-18  36527.61
# 100             202    IQ627690  2004-11-08  33594.58
# 101             204    GC697638  2004-08-13  51152.86
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [162 rows x 4 columns]

# %%
df.loc[mask] # sale lo mismo
# Out:
#      customernumber checknumber paymentdate    amount
# 97              201    DP677013  2003-10-20  23908.24
# 98              201    OO846801  2004-06-15  37258.94
# 99              202    HI358554  2003-12-18  36527.61
# 100             202    IQ627690  2004-11-08  33594.58
# 101             204    GC697638  2004-08-13  51152.86
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [162 rows x 4 columns]

# %%
df[(df['amount']>400) & (df['customernumber']>200)] #sale lo mismo sin utilizar loc
# Out:
#      customernumber checknumber paymentdate    amount
# 97              201    DP677013  2003-10-20  23908.24
# 98              201    OO846801  2004-06-15  37258.94
# 99              202    HI358554  2003-12-18  36527.61
# 100             202    IQ627690  2004-11-08  33594.58
# 101             204    GC697638  2004-08-13  51152.86
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [162 rows x 4 columns]

# %% [markdown]
# 7. Escribe un programa Pandas que utilice loc para cambiar en el valor de ammount de las filas que cumplan con una condición.

# %%
df
# Out:
#      customernumber checknumber paymentdate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [259 rows x 4 columns]

# %%
mask=(df['amount']>400) & (df['customernumber']>200)
df[mask]
# Out:
#      customernumber checknumber paymentdate    amount
# 97              201    DP677013  2003-10-20  23908.24
# 98              201    OO846801  2004-06-15  37258.94
# 99              202    HI358554  2003-12-18  36527.61
# 100             202    IQ627690  2004-11-08  33594.58
# 101             204    GC697638  2004-08-13  51152.86
# ..              ...         ...         ...       ...
# 254             495    BH167026  2003-12-26  59265.14
# 255             495    FN155234  2004-05-14   6276.60
# 256             496    EU531600  2005-05-25  30253.75
# 257             496    MB342426  2003-07-16  32077.44
# 258             496     MN89921  2004-12-31  52166.00
#
# [162 rows x 4 columns]

# %%
#quiero escoger una columna
df.loc[mask,'amount'] # sin loc no me filtra la columna
# Out:
# 97     23908.24
# 98     37258.94
# 99     36527.61
# 100    33594.58
# 101    51152.86
#          ...
# 254    59265.14
# 255     6276.60
# 256    30253.75
# 257    32077.44
# 258    52166.00
# Name: amount, Length: 162, dtype: float64

# %%
df.loc[mask,'amount']=0 #ojo que ya ha hecho la sustitución

# %%
df[mask]
# Out:
#      customernumber checknumber paymentdate  amount
# 97              201    DP677013  2003-10-20     0.0
# 98              201    OO846801  2004-06-15     0.0
# 99              202    HI358554  2003-12-18     0.0
# 100             202    IQ627690  2004-11-08     0.0
# 101             204    GC697638  2004-08-13     0.0
# ..              ...         ...         ...     ...
# 254             495    BH167026  2003-12-26     0.0
# 255             495    FN155234  2004-05-14     0.0
# 256             496    EU531600  2005-05-25     0.0
# 257             496    MB342426  2003-07-16     0.0
# 258             496     MN89921  2004-12-31     0.0
#
# [162 rows x 4 columns]

# %%
#para más cambios en columnas
df.loc[mask,('amount','paymentdate')]=(0,'2025-01-01') #ojo que no sale salida
df[mask]
# Out:
#      customernumber checknumber paymentdate  amount
# 97              201    DP677013  2025-01-01     0.0
# 98              201    OO846801  2025-01-01     0.0
# 99              202    HI358554  2025-01-01     0.0
# 100             202    IQ627690  2025-01-01     0.0
# 101             204    GC697638  2025-01-01     0.0
# ..              ...         ...         ...     ...
# 254             495    BH167026  2025-01-01     0.0
# 255             495    FN155234  2025-01-01     0.0
# 256             496    EU531600  2025-01-01     0.0
# 257             496    MB342426  2025-01-01     0.0
# 258             496     MN89921  2025-01-01     0.0
#
# [162 rows x 4 columns]

# %% [markdown]
# 8. Escribe un programa Pandas que utilice .loc para dividir un DataFrame en función de las etiquetas de filas y columnas.

# %%
# pendiente

# %% [markdown]
# 9. Escribe un programa Pandas que utilice .loc para segmentar un DataFrame multi-índice.

# %%
#pendiente
